# %%
import matplotlib.pyplot as plt
from numpy import *

# %%
a = 1
b = 1.2

wpts = linspace(0,2*pi,100)
x = array([a*cos(w) for w in wpts])
y = array([b*sin(w) for w in wpts])
z = (x/a)**2 + (y/b)**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(wpts,z)
